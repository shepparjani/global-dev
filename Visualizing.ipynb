# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

cchange_df = pd. read_csv('resources/combined2018data.csv')
#cchange_df['Country Name'].plot()
cchange_df.plot(kind='scatter', x='Electricity_2018', y='CO2percap_2018')
# Out:
# <AxesSubplot:xlabel='Electricity_2018', ylabel='CO2percap_2018'>
